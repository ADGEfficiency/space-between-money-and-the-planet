# %% [markdown]
# # Experiment Results Viewer

# %%
import sys
sys.path.append("..")
from results import *

# %%
import pandas as pd
monthly = pd.read_parquet("../data/results/monthly.parquet")
annual = pd.read_parquet("../data/results/annual.parquet")

# %%
monthly.head(2)
# Out:
#             carbon-cost  carbon-profit  carbon-emissions  carbon-emissions-benefit    price-cost  price-profit  price-emissions  price-emissions-benefit  variance-cost  variance-emissions  variance-profit  carbon-price  year  month  day        date
# date
# 2014-01-01 -1125.286799    1125.286799       -332.590995                332.590995 -54524.370207  54524.370207        12.503406               -12.503406  -53399.083408          345.094401     53399.083408    154.737612  2014      1    1  2014-01-01
# 2014-02-01  1904.062843   -1904.062843       -216.187848                216.187848  -9110.623956   9110.623956        57.523703               -57.523703  -11014.686799          273.711551     11014.686799     40.241951  2014      2    1  2014-02-01

# %%
plot_monthly_benefit(monthly)

# %%
plot_monthly(monthly)

# %%
plot_annual(annual)
